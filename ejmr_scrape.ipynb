# %%
from bs4 import BeautifulSoup
import csv
import urllib2
import datetime

# %%
def ejmr_scrape(pg_num):
    """
    title: post title including link to post
    num_posts: number of posts as of download date
    views: number of views as of download date
    votes
    """
#     print "{0}".format(pg_num)

    if pg_num % 10 == 0:
        
        print "Webpage number: {0}".format(pg_num)
    
    page = urllib2.urlopen("https://www.econjobrumors.com/page/{0}".format(pg_num))
    soup = BeautifulSoup(page)

    table = soup.find("table", id="latest").find_all("tr") # table containing posts

    ejmr_filename = "ejmr_data/ejmr_pg{0}.csv".format(pg_num)

    header_row = ["title",
                  "num_posts",
                  "views",
                  "votes",
                  "freshness",
                  "download_time"
                 ]

    with open(ejmr_filename, "wb") as f:

        writeFile = csv.writer(f, quoting=csv.QUOTE_NONNUMERIC)

        writeFile.writerow(header_row)

        for tb in table:

            row = []

            for elem in tb.find_all("td"):

                # remove empty element from list
                elem_list = [e.encode('utf-8').strip() for e in elem]
                try:
                    elem_list = filter(None, elem_list)

                except:

                    print "no blank"

                # get only first element of list (addresses case where title includes page number links next to them---e.g. Top theorists graduating next year? - 23…8910)
                elem_list_first = elem_list[0]
                row.append(elem_list_first)

            if row:  # write row only if non-empty
                row.append(datetime.datetime.now())
                writeFile.writerow(row)

# %%
# pg_start = 2
# pg_end = 1000

# pg_start = 1000
# pg_end = 3000

# pg_start = 3000
# pg_end = 5000

# pg_start = 5000
# pg_end = 7220

pg_start = 7220
pg_end = 8250

# last page on ejmr: 8244

for pg_num in xrange(pg_start, pg_end):
    ejmr_scrape(pg_num)

print "Finished"
# Out:
# Webpage number: 7220
# Webpage number: 7230
# Webpage number: 7240
# Webpage number: 7250
# Webpage number: 7260
# Webpage number: 7270
# Webpage number: 7280
# Webpage number: 7290
# Webpage number: 7300
# Webpage number: 7310
# Webpage number: 7320
# Webpage number: 7330
# Webpage number: 7340
# Webpage number: 7350
# Webpage number: 7360
# Webpage number: 7370
# Webpage number: 7380
# Webpage number: 7390
# Webpage number: 7400
# Webpage number: 7410
# Webpage number: 7420
# Webpage number: 7430
# Webpage number: 7440
# Webpage number: 7450
# Webpage number: 7460
# Webpage number: 7470
# Webpage number: 7480
# Webpage number: 7490
# Webpage number: 7500
# Webpage number: 7510
# Webpage number: 7520
# Webpage number: 7530
# Webpage number: 7540
# Webpage number: 7550
# Webpage number: 7560
# Webpage number: 7570
# Webpage number: 7580
# Webpage number: 7590
# Webpage number: 7600
# Webpage number: 7610
# Webpage number: 7620
# Webpage number: 7630
# Webpage number: 7640
# Webpage number: 7650
# Webpage number: 7660
# Webpage number: 7670
# Webpage number: 7680
# Webpage number: 7690
# Webpage number: 7700
# Webpage number: 7710
# Webpage number: 7720
# Webpage number: 7730
# Webpage number: 7740
# Webpage number: 7750
# Webpage number: 7760
# Webpage number: 7770
# Webpage number: 7780
# Webpage number: 7790
# Webpage number: 7800
# Webpage number: 7810
# Webpage number: 7820
# Webpage number: 7830
# Webpage number: 7840
# Webpage number: 7850
# Webpage number: 7860
# Webpage number: 7870
# Webpage number: 7880
# Webpage number: 7890
# Webpage number: 7900
# Webpage number: 7910
# Webpage number: 7920
# Webpage number: 7930
# Webpage number: 7940
# Webpage number: 7950
# Webpage number: 7960
# Webpage number: 7970
# Webpage number: 7980
# Webpage number: 7990
# Webpage number: 8000
# Webpage number: 8010
# Webpage number: 8020
# Webpage number: 8030
# Webpage number: 8040
# Webpage number: 8050
# Webpage number: 8060
# Webpage number: 8070
# Webpage number: 8080
# Webpage number: 8090
# Webpage number: 8100
# Webpage number: 8110
# Webpage number: 8120
# Webpage number: 8130
# Webpage number: 8140
# Webpage number: 8150
# Webpage number: 8160
# Webpage number: 8170
# Webpage number: 8180
# Webpage number: 8190
# Webpage number: 8200
# Webpage number: 8210
# Webpage number: 8220
# Webpage number: 8230
# Webpage number: 8240
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-72-6b2940165876> in <module>()
#      17
#      18 for pg_num in xrange(pg_start, pg_end):
# ---> 19     ejmr_scrape(pg_num)
#      20
#      21 print "Finished"
#
# <ipython-input-70-df937e13ef47> in ejmr_scrape(pg_num)
#      15     soup = BeautifulSoup(page)
#      16
# ---> 17     table = soup.find("table", id="latest").find_all("tr") # table containing posts
#      18
#      19     ejmr_filename = "ejmr_data/ejmr_pg{0}.csv".format(pg_num)
#
# AttributeError: 'NoneType' object has no attribute 'find_all'
